# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def new_line(n=1):
    for i in range(n):
        print()

# %%
df = pd.read_csv('data/heart.csv')

# %%
# 1
df.shape
# df.size
# Out:
# (303, 14)

# %%
# 2
df.columns
# print(len(df.columns))
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='str')

# %%
# 3
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# 4
print()

# %%
# 5

# print()


data = {
    "feature": [
        "age", "sex", "cp", "trestbps", "chol",
        "fbs", "restecg", "thalach", "exang",
        "oldpeak", "slope", "ca", "thal", "target"
    ],

    "type": [
        "عددی", "دودویی", "دسته‌ای", "عددی", "عددی",
        "دودویی", "دسته‌ای", "عددی", "دودویی",
        "عددی", "دسته‌ای", "عددی", "دسته‌ای", "دودویی"
    ],

    "description": [
        "سن بیمار. با افزایش سن ریسک بیماری‌های قلبی بیشتر می‌شود.",
        "جنسیت بیمار.",
        "نوع درد قفسه سینه بیمار.",
        "فشار خون در حالت استراحت.",
        "میزان کلسترول خون.",
        "قند خون ناشتا.",
        "نتیجه الکتروکاردیوگرام در حالت استراحت.",
        "بیشترین ضربان قلب ثبت شده هنگام فعالیت.",
        "وجود آنژین ناشی از ورزش.",
        "میزان افت ST در تست ورزش نسبت به حالت استراحت.",
        "شیب بخش ST در اوج ورزش.",
        "تعداد رگ‌های اصلی قلب که در آن‌ها انسداد یا مشکل مشاهده شده است.",
        "نتیجه تست تالاسمی یا اسکن جریان خون قلب.",
        "متغیر هدف: وجود یا عدم وجود بیماری قلبی."
    ]
}

features_df = pd.DataFrame(data)

features_df
# Out:
#      feature     type                                        description
# 0        age     عددی  سن بیمار. با افزایش سن ریسک بیماری‌های قلبی بی...
# 1        sex   دودویی                                       جنسیت بیمار.
# 2         cp  دسته‌ای                           نوع درد قفسه سینه بیمار.
# 3   trestbps     عددی                          فشار خون در حالت استراحت.
# 4       chol     عددی                                 میزان کلسترول خون.
# 5        fbs   دودویی                                     قند خون ناشتا.
# 6    restecg  دسته‌ای            نتیجه الکتروکاردیوگرام در حالت استراحت.
# 7    thalach     عددی            بیشترین ضربان قلب ثبت شده هنگام فعالیت.
# 8      exang   دودویی                           وجود آنژین ناشی از ورزش.
# 9    oldpeak     عددی     میزان افت ST در تست ورزش نسبت به حالت استراحت.
# 10     slope  دسته‌ای                            شیب بخش ST در اوج ورزش.
# 11        ca     عددی  تعداد رگ‌های اصلی قلب که در آن‌ها انسداد یا مش...
# ...

# %%
# 6
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# 7
df.isnull().sum() / len(df)*  100
# Out:
# age         0.0
# sex         0.0
# cp          0.0
# trestbps    0.0
# chol        0.0
# fbs         0.0
# restecg     0.0
# thalach     0.0
# exang       0.0
# oldpeak     0.0
# slope       0.0
# ca          0.0
# thal        0.0
# target      0.0
# dtype: float64

# %%
# 8
duplicate_count = df.duplicated().sum()
bool(duplicate_count)
# Out:
# True

# %%
# 9
duplicate_percent = (duplicate_count / len(df)) * 100
if duplicate_count:
    print(duplicate_count)
    print(duplicate_percent)
# Out:
# 1
# 0.33003300330033003

# %%
# 10
target_count = df['target'].value_counts()
print(target_count)
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
sns.countplot(x='target', data=df)
plt.grid()
plt.yticks(np.arange(0,180,5))
# Out:
# ([<matplotlib.axis.YTick at 0x7f6e2776f380>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 5, '5'),
#   Text(0, 10, '10'),
#   Text(0, 15, '15'),
#   Text(0, 20, '20'),
#   Text(0, 25, '25'),
#   Text(0, 30, '30'),
#   Text(0, 35, '35'),
#   Text(0, 40, '40'),
#   Text(0, 45, '45'),
#   Text(0, 50, '50'),
#   Text(0, 55, '55'),
#   Text(0, 60, '60'),
#   Text(0, 65, '65'),
#   Text(0, 70, '70'),
#   Text(0, 75, '75'),
#   Text(0, 80, '80'),
#   Text(0, 85, '85'),
#   Text(0, 90, '90'),
#   Text(0, 95, '95'),
#   Text(0, 100, '100'),
#   Text(0, 105, '105'),
#   Text(0, 110, '110'),
#   Text(0, 115, '115'),
#   Text(0, 120, '120'),
#   Text(0, 125, '125'),
#   Text(0, 130, '130'),
#   Text(0, 135, '135'),
#   Text(0, 140, '140'),
#   Text(0, 145, '145'),
#   Text(0, 150, '150'),
#   Text(0, 155, '155'),
#   Text(0, 160, '160'),
#   Text(0, 165, '165'),
#   Text(0, 170, '170'),
#   Text(0, 175, '175')])

# %%
df['target'].value_counts().plot.pie(
    autopct='%1.1f%%',
    labels=['Disease','No Disease']
)
# Out:
# <Axes: >

# %%
# 11
df['target'].value_counts() / len(df) * 100
# Out:
# target
# 1    54.455446
# 0    45.544554
# Name: count, dtype: float64

# %%
(df['target'].value_counts() / len(df) * 100).plot(kind='bar')
plt.grid(axis='y')
plt.yticks(np.arange(0,60,2))
# Out:
# ([<matplotlib.axis.YTick at 0x7f6e253ce0d0>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 2, '2'),
#   Text(0, 4, '4'),
#   Text(0, 6, '6'),
#   Text(0, 8, '8'),
#   Text(0, 10, '10'),
#   Text(0, 12, '12'),
#   Text(0, 14, '14'),
#   Text(0, 16, '16'),
#   Text(0, 18, '18'),
#   Text(0, 20, '20'),
#   Text(0, 22, '22'),
#   Text(0, 24, '24'),
#   Text(0, 26, '26'),
#   Text(0, 28, '28'),
#   Text(0, 30, '30'),
#   Text(0, 32, '32'),
#   Text(0, 34, '34'),
#   Text(0, 36, '36'),
#   Text(0, 38, '38'),
#   Text(0, 40, '40'),
#   Text(0, 42, '42'),
#   Text(0, 44, '44'),
#   Text(0, 46, '46'),
#   Text(0, 48, '48'),
#   Text(0, 50, '50'),
#   Text(0, 52, '52'),
#   Text(0, 54, '54'),
#   Text(0, 56, '56'),
#   Text(0, 58, '58')])

# %%
# 12

df[['age','trestbps','chol','thalach','oldpeak','ca']].describe()
# Out:
#               age    trestbps        chol     thalach     oldpeak          ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337  131.623762  246.264026  149.646865    1.039604    0.729373
# std      9.082101   17.538143   51.830751   22.905161    1.161075    1.022606
# min     29.000000   94.000000  126.000000   71.000000    0.000000    0.000000
# 25%     47.500000  120.000000  211.000000  133.500000    0.000000    0.000000
# 50%     55.000000  130.000000  240.000000  153.000000    0.800000    0.000000
# 75%     61.000000  140.000000  274.500000  166.000000    1.600000    1.000000
# max     77.000000  200.000000  564.000000  202.000000    6.200000    4.000000

# %%
# 13

mean_addady = df[['age','trestbps','chol','thalach','oldpeak','ca']].mean()
median_addady = df[['age','trestbps','chol','thalach','oldpeak','ca']].median()
mode_addady = df[['age','trestbps','chol','thalach','oldpeak','ca']].mode()

print(mean_addady)
new_line(4)
print(median_addady)
new_line(4)
print(mode_addady)
# Out:
# age          54.366337
# trestbps    131.623762
# chol        246.264026
# thalach     149.646865
# oldpeak       1.039604
# ca            0.729373
# dtype: float64
#
#
#
#
# age          55.0
# trestbps    130.0
# chol        240.0
# thalach     153.0
# oldpeak       0.8
# ca            0.0
# dtype: float64
#
#
#
#
#     age  trestbps  chol  thalach  oldpeak   ca
# 0  58.0     120.0   197    162.0      0.0  0.0
# 1   NaN       NaN   204      NaN      NaN  NaN
# 2   NaN       NaN   234      NaN      NaN  NaN

# %%
# 14

var_addady = df[['age','trestbps','chol','thalach','oldpeak','ca']].var()
std_addady = df[['age','trestbps','chol','thalach','oldpeak','ca']].std()

print(var_addady)
new_line(4)
print(std_addady)
# Out:
# age           82.484558
# trestbps     307.586453
# chol        2686.426748
# thalach      524.646406
# oldpeak        1.348095
# ca             1.045724
# dtype: float64
#
#
#
#
# age          9.082101
# trestbps    17.538143
# chol        51.830751
# thalach     22.905161
# oldpeak      1.161075
# ca           1.022606
# dtype: float64

# %%
# 15
cols_1 = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca']

for col in cols_1:
    plt.figure()
    sns.histplot(df[col], kde=True)
    plt.title(col)
    plt.ylabel('Count')
    plt.show()

# %%
# 16


for col in cols_1:
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
# 17


for col in cols_1:
    sns.kdeplot(df[col], fill=True)
    plt.title(col)
    plt.show()

# %%
# 18

cols_2 = ['cp', 'restecg', 'slope', 'thal']

for col in cols_2:
    new_line(1)
    print(df[col].value_counts())
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64
#
# restecg
# 1    152
# 0    147
# 2      4
# Name: count, dtype: int64
#
# slope
# 2    142
# 1    140
# 0     21
# Name: count, dtype: int64
#
# thal
# 2    166
# 3    117
# 1     18
# 0      2
# Name: count, dtype: int64

# %%
# 19
for col in cols_2:
    sns.countplot(x=col, data=df)
    plt.title(col)
    plt.grid()
    plt.yticks(np.arange(0, 175, 5))
    plt.show()

# %%
# 20

print(df['sex'].value_counts())
new_line(2)
print(df['sex'].value_counts() / len(df) * 100)


sns.countplot(x='sex', data=df)
plt.grid()
plt.yticks(np.arange(0,220,10))
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64
#
#
# sex
# 1    68.316832
# 0    31.683168
# Name: count, dtype: float64
# ([<matplotlib.axis.YTick at 0x7f6e226ef390>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 10, '10'),
#   Text(0, 20, '20'),
#   Text(0, 30, '30'),
#   Text(0, 40, '40'),
#   Text(0, 50, '50'),
#   Text(0, 60, '60'),
#   Text(0, 70, '70'),
#   Text(0, 80, '80'),
#   Text(0, 90, '90'),
#   Text(0, 100, '100'),
#   Text(0, 110, '110'),
#   Text(0, 120, '120'),
#   Text(0, 130, '130'),
#   Text(0, 140, '140'),
#   Text(0, 150, '150'),
#   Text(0, 160, '160'),
#   Text(0, 170, '170'),
#   Text(0, 180, '180'),
#   Text(0, 190, '190'),
#   Text(0, 200, '200'),
#   Text(0, 210, '210')])

# %%
# 21

for col in cols_1:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x='target', y=col, data=df)
    plt.title(col)
    plt.show()

# %%
for col in cols_1:
    plt.figure(figsize=(6, 6))
    sns.violinplot(x='target', y=col, data=df)
    plt.title(f'Boxplot of {col} by target')
    plt.show()

# %%
# 22

print(df[df['target'] == 0]['age'].mean())
print(df[df['target'] == 1]['age'].mean())
# Out:
# 56.60144927536232
# 52.4969696969697

# %%
# 23
print(df[df['target'] == 0]['chol'].mean())
print(df[df['target'] == 1]['chol'].mean())
# Out:
# 251.08695652173913
# 242.23030303030302

# %%
# 24
print(df[df['target'] == 0]['thalach'].mean())
# print(df[df['target'] == 0]['thalach'].max())
new_line(2)
print(df[df['target'] == 1]['thalach'].mean())
# print(df[df['target'] == 1]['thalach'].max())
# Out:
# 139.1014492753623
#
#
# 158.46666666666667

# %%
# 25
oldpeak_to_target = df.groupby('target')['oldpeak'].agg('mean')
print(oldpeak_to_target)
# Out:
# target
# 0    1.585507
# 1    0.583030
# Name: oldpeak, dtype: float64

# %%
# 26

# for cos in cols_2:
    # print(f"{cos} - Target")
pd.crosstab(df['cp'], df['target'])
    # print(ct_1)
    # new_line(2)
    # print("\n")
# print(cols_2)
# Out:
# target    0   1
# cp
# 0       104  39
# 1         9  41
# 2        18  69
# 3         7  16

# %%
pd.crosstab(df['restecg'], df['target'])
# Out:
# target    0   1
# restecg
# 0        79  68
# 1        56  96
# 2         3   1

# %%
pd.crosstab(df['slope'], df['target'])
# Out:
# target   0    1
# slope
# 0       12    9
# 1       91   49
# 2       35  107

# %%
pd.crosstab(df['thal'], df['target'])
# Out:
# target   0    1
# thal
# 0        1    1
# 1       12    6
# 2       36  130
# 3       89   28

# %%
# 27
print(df.groupby('sex')['target'].mean() * 100)
new_line(2)
print(df.groupby('sex')['target'].value_counts())
# Out:
# sex
# 0    75.000000
# 1    44.927536
# Name: target, dtype: float64
#
#
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
# 28

df.groupby('cp')['target'].mean()
# Out:
# cp
# 0    0.272727
# 1    0.820000
# 2    0.793103
# 3    0.695652
# Name: target, dtype: float64

# %%
# 29
df.groupby('exang')['target'].mean() * 100
# Out:
# exang
# 0    69.607843
# 1    23.232323
# Name: target, dtype: float64

# %%
# 30
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
# 31
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# 32

df.corr()['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
# 33
df.corr()['target'].sort_values(ascending=True)
# Out:
# exang      -0.436757
# oldpeak    -0.430696
# ca         -0.391724
# thal       -0.344029
# sex        -0.280937
# age        -0.225439
# trestbps   -0.144931
# chol       -0.085239
# fbs        -0.028046
# restecg     0.137230
# slope       0.345877
# thalach     0.421741
# cp          0.433798
# target      1.000000
# Name: target, dtype: float64

# %%
# # 34

# sloope , talach
# target , cp
# target , talach

#####read text#####

# %%
# 35
plt.figure()
sns.scatterplot(data=df, x='age', y='chol', hue='target')
plt.title('age , chol')
# Out:
# Text(0.5, 1.0, 'age , chol')

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='thalach', hue='target')
plt.title('age , thalach')
# Out:
# Text(0.5, 1.0, 'age , thalach')

# %%
plt.figure()
sns.scatterplot(data=df, x='chol', y='trestbps', hue='target')
plt.title('chol , trestbps')
# Out:
# Text(0.5, 1.0, 'chol , trestbps')

# %%
# 36
importants_1 = ['age', 'thalach', 'oldpeak', 'ca', 'target']


sns.pairplot(
    data=df[importants_1],
    hue='target',
    diag_kind='hist'
)

plt.show()

# %%
# 37


number_vlue =['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

target_of_number_vlue = df.groupby('target')[number_vlue].mean()

target_of_number_vlue
# Out:
#               age    trestbps        chol     thalach   oldpeak
# target
# 0       56.601449  134.398551  251.086957  139.101449  1.585507
# 1       52.496970  129.303030  242.230303  158.466667  0.583030

# %%
# 38

df.groupby(["sex", "target"]).mean()
# Out:
#                   age        cp    trestbps        chol       fbs   restecg  \
# sex target
# 0   0       59.041667  0.166667  146.125000  274.958333  0.250000  0.541667
#     1       54.555556  1.333333  128.736111  256.750000  0.083333  0.583333
# 1   0       56.087719  0.543860  131.929825  246.061404  0.140351  0.429825
#     1       50.903226  1.408602  129.741935  230.989247  0.182796  0.602151
#
#                thalach     exang   oldpeak     slope        ca      thal
# sex target
# 0   0       142.416667  0.583333  1.841667  0.958333  1.291667  2.500000
#     1       154.027778  0.111111  0.554167  1.583333  0.305556  2.000000
# 1   0       138.403509  0.543860  1.531579  1.210526  1.140351  2.552632
#     1       161.903226  0.161290  0.605376  1.602151  0.408602  2.215054

# %%
# 39
df.groupby(["cp", "target"]).mean()
# Out:
#                  age       sex    trestbps        chol       fbs   restecg  \
# cp target
# 0  0       56.298077  0.798077  133.692308  251.932692  0.163462  0.442308
#    1       54.076923  0.538462  127.564103  245.333333  0.025641  0.564103
# 1  0       57.444444  0.777778  138.444444  263.444444  0.111111  0.333333
#    1       50.024390  0.609756  126.195122  240.682927  0.097561  0.682927
# 2  0       58.500000  0.944444  135.055556  239.000000  0.166667  0.500000
#    1       52.217391  0.507246  129.159420  244.260870  0.202899  0.623188
# 3  0       55.142857  1.000000  138.000000  253.714286  0.142857  0.571429
#    1       56.187500  0.750000  142.125000  229.875000  0.250000  0.312500
#
#               thalach     exang   oldpeak     slope        ca      thal
# cp target
# 0  0       136.057692  0.673077  1.683654  1.134615  1.240385  2.576923
#    1       152.487179  0.256410  0.582051  1.589744  0.230769  2.102564
# ...

# %%
# 40


# در درجه بندی افراد با درد صفر افراد مبتلا میانگین سنی پنجاه و چهار سال افراد غیرمبتلا میانگین سنی پنجاه و شش سال در درجه درد یک افراد مبتلا با میانگین سنی پنجاه سال میانگین سنی غیرمبتلا پنجاه و هفت سال افراد با درجه درد قفس سینه دو افراد مبتلا میانگین سنی پنجاه و دو سال میانگین سنی افراد غیرمبتلا پنجاه و هشت سال افراد باداشتن درجه درد سه میانگین سنی افراد مبتلا پنجاه و شش سال میانگین سنی افراد غیرمبتلا پنجاه و پنج سال

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)
